# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

from helpers.harris_corner import *
from helpers.utils import load_img_gray_float32, compute_gradient, save_img
from helpers.motion_tracking import *

# %% [markdown]
# # 1. Test Functions

# %%
img_path = "../images/shelves.jpg"

# %%
img = load_img_gray_float32(img_path, if_show=True)

# %%
Ix, Iy = compute_gradient(img, if_show=True)

# %% [markdown]
# # 2. Harris Corners

# %%
inds_r, inds_c = compute_features(img, min_dist_pix=200, if_show=True)
len(inds_r), len(inds_c)
# Out:
# (996, 996)

# %% [markdown]
# # 3. Optical Flow

# %%
img1 = load_img_gray_float32("../images/yos.10.pnm", if_show=True)
# save_img(img1, "../outputs/yos_10.png")

# %%
img2 = load_img_gray_float32("../images/yos.11.pnm", if_show=True)
# save_img(img2, "../outputs/yos_11.png")

# %%
pts_x, pts_y, ux, uy = optical_flow_with_harris_corners(img1, img2)

# %% [markdown]
# # 3. Line Feature Extractor

# %%
H, W = 200, 300
img = np.zeros((H, W), dtype=np.float32)
rhos = [10, 20, 30, 40, 50]
thetas = [0, np.pi / 4, np.pi / 2, np.pi / 4 * 3, np.pi]
end_pts = convert_rho_theta_to_xy((H, W), rhos, thetas)

# %%
end_pts
# Out:
# array([[   10, -2000,    10,  2000],
#        [ 2135, -1400, -2107,  1428],
#        [ 3000,    29, -3000,    30],
#        [ 2093,  1442, -2149, -1385],
#        [  -49,  2000,   -50, -2000]])

# %%
img_c = draw_lines(img, end_pts)

# %%
sigma = 0.05
img = load_img_gray_float32("../images/homography_1.png", if_show=True)
img += + sigma * np.random.randn(*img.shape)
plt.imshow(img, cmap="gray")
plt.colorbar()

# %%
th1, th2 = 50, 150
win_size = 5
img_blur = cv2.GaussianBlur(img, ksize=(win_size, win_size), sigmaX=0)
edges = cv2.Canny((img_blur * 255).astype(np.uint8), th1, th2, edges=None, apertureSize=3)
plt.imshow(edges, cmap="gray")
plt.colorbar()

# %%
lines = extract_line_features(img, if_show=True, threshold=340, if_save_lines=True, minLineLength=200,
                              lines_path="../outputs/hough_lines.png", 
                              lines_path_hough_P="../outputs/hough_lines_p.png")
